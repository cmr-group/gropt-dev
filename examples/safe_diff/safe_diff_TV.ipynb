# %%
import matplotlib.pyplot as plt
import numpy as np
from timeit import default_timer as timer

import gropt_dev as gropt

# %%
gropt.gropt_wrapper.set_verbose(4)
gparams = gropt.GroptParams()
gparams.diff_init(dt=200e-6)

gparams.add_gmax(.08)
gparams.add_smax(200)
gparams.add_moment(0,0.0)
gparams.add_moment(1,0.0)
gparams.add_moment(2,0.0)
gparams.add_bvalue(750,1)

start_t = timer()
gparams.init()
gparams.solve()
out = gparams.get_out()
stop_t = timer()

print(f'Final Good: {gparams.final_good>0}   Solve time: {1000*(stop_t-start_t):.1f} ms')

plt.figure(figsize=(6,3))
tt_ms = np.arange(out.size)*gparams.dt*1e3
plt.plot(tt_ms, out)
plt.show()

plt.figure(figsize=(6,3))
plt.plot(tt_ms[:-1], np.diff(out)/gparams.dt)
plt.show()

safe = gropt.gropt_wrapper.get_SAFE(out, gparams.dt)
print(f'Max SAFE {np.max(safe):.3f}')
plt.figure()
plt.plot(safe)
# Out:
# Final Good: True   Solve time: 59.0 ms
# Max SAFE 1.389

# %%
gropt.gropt_wrapper.set_verbose(4)
gparams = gropt.GroptParams()
gparams.diff_init(dt=200e-6)

gparams.add_gmax(.08)
gparams.add_smax(200)
gparams.add_moment(0,0.0)
gparams.add_moment(1,0.0)
gparams.add_moment(2,0.0)
gparams.add_bvalue(750,1)
gparams.add_TV(20, 1)

start_t = timer()
gparams.init()
gparams.solve(n_iter=10000)
out = gparams.get_out()
stop_t = timer()

print(f'Final Good: {gparams.final_good>0}   Solve time: {1000*(stop_t-start_t):.1f} ms')

plt.figure(figsize=(6,3))
tt_ms = np.arange(out.size)*gparams.dt*1e3
plt.plot(tt_ms, out)
plt.show()

plt.figure(figsize=(6,3))
plt.plot(tt_ms[:-1], np.diff(out)/gparams.dt)
plt.show()

safe = gropt.gropt_wrapper.get_SAFE(out, gparams.dt)
print(f'Max SAFE {np.max(safe):.3f}')
plt.figure()
plt.plot(safe)
# Out:
# Final Good: True   Solve time: 69.8 ms
# Max SAFE 1.376

# %%
gropt.gropt_wrapper.set_verbose(4)
gparams = gropt.GroptParams()
gparams.diff_init(dt=200e-6)

gparams.add_gmax(.08)
gparams.add_smax(200)
gparams.add_moment(0,0.0)
gparams.add_moment(1,0.0)
gparams.add_moment(2,0.0)
gparams.add_bvalue(750,1)

start_t = timer()
gparams.init()
gparams.solve(ils_tik_lam=100.0)
out = gparams.get_out()
stop_t = timer()

print(f'Final Good: {gparams.final_good>0}   Solve time: {1000*(stop_t-start_t):.1f} ms')

plt.figure(figsize=(6,3))
tt_ms = np.arange(out.size)*gparams.dt*1e3
plt.plot(tt_ms, out)
plt.show()

plt.figure(figsize=(6,3))
plt.plot(tt_ms[:-1], np.diff(out)/gparams.dt)
plt.show()

safe = gropt.gropt_wrapper.get_SAFE(out, gparams.dt)
print(f'Max SAFE {np.max(safe):.3f}')
plt.figure()
plt.plot(safe)
# Out:
# Final Good: True   Solve time: 87.6 ms
# Max SAFE 1.183
